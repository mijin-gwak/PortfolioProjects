# %%
# Import libraries

import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None

# Read in the data
df = pd.read_csv(r'C:\Users\krijn\OneDrive\Bureaublad\Mijin\Portfolio Projects\movies.csv')

# %%
# First 5 rows of the data

df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# Check missing data

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# name - 0.0%
# rating - 0.0%
# genre - 0.0%
# year - 0.0%
# released - 0.0%
# score - 0.0%
# votes - 0.0%
# director - 0.0%
# writer - 0.0%
# star - 0.0%
# country - 0.0%
# budget - 0.0%
# gross - 0.0%
# company - 0.0%
# runtime - 0.0%

# %%
# Data types of the columns

df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# We do not need decimals for budget and gross

df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')

# %%
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 5416                               Bad Boys for Life          R     Action
# 5417                              Sonic the Hedgehog         PG     Action
# 5418                                        Dolittle         PG  Adventure
# 5419                            The Call of the Wild         PG  Adventure
# 5420                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
# The year in the released column and year column do not match
# Solution: extract the year from released column

# Convert the column into string and then take substring
df['released_year'] = df['released'].str.extract(pat='([0-9]{4})').astype(int)

df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 5416                               Bad Boys for Life          R     Action
# 5417                              Sonic the Hedgehog         PG     Action
# 5418                                        Dolittle         PG  Adventure
# 5419                            The Call of the Wild         PG  Adventure
# 5420                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
# Order by the gross revenue

df = df.sort_values(by = ['gross'], ascending=False) # descending

df

# To see all the rows, first run the following
# pd.set_option('display.max_rows', None)
# Out:
#                                             name     rating   genre  year  \
# 3731                                      Avatar      PG-13  Action  2009
# 5302                           Avengers: Endgame      PG-13  Action  2019
# 1795                                     Titanic      PG-13   Drama  1997
# 4730  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 5158                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 3898                                 Tanner Hall          R   Drama  2009
# 1378                  Philadelphia Experiment II      PG-13  Action  1993
# 2286                                Ginger Snaps  Not Rated   Drama  2000
# 154                                     Parasite          R  Horror  1982
# 1920                                  Trojan War      PG-13  Comedy  1997
#
#                                released  score      votes  \
# ...

# %%
# Check duplicates

df['company'].drop_duplicates().sort_values(ascending=False)

# It seems that there are no duplicates
# If there are, run the following:
# df.drop_duplicates()
# Out:
# 5101                                thefyzz
# 3920                            micro_scope
# 2551                               i5 Films
# 4834                             i am OTHER
# 4537                                   erbp
#                        ...
# 216                        1818 Productions
# 1727                          1492 Pictures
# 1785                        .406 Production
# 5375    "Weathering With You" Film Partners
# 2850        "DIA" Productions GmbH & Co. KG
# Name: company, Length: 1475, dtype: object

# %%
# Hypothesis 1: The more the budget, the more the gross revenue
# Hypothesis 2: Certain companies elicit more gross revenue than others

# %%
# Scatter plot with budget vs gross

plt.scatter(x=df['budget'], y=df['gross'])
plt.title('Budget vs Gross Earnings')
plt.xlabel('Gross Earnings')
plt.ylabel('Budget for film')
plt.show()

# %%
df.head()
# Out:
#                                             name rating   genre  year  \
# 3731                                      Avatar  PG-13  Action  2009
# 5302                           Avengers: Endgame  PG-13  Action  2019
# 1795                                     Titanic  PG-13   Drama  1997
# 4730  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 5158                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 3731  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 5302     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 1795  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 4730  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 5158     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country     budget  \
# ...

# %%
# Plot budget vs gross using seaborn

sns.regplot(x='budget', y='gross', data=df, 
scatter_kws={'color':'red'}, line_kws={'color':'blue'})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
# Looking at the correlation (for numeric columns only)
# Default: Pearson
# Other options: (method = 'spearman') or (method = 'kendall')

df.corr(numeric_only = True)
# Out:
#                    year     score     votes    budget     gross   runtime  \
# year           1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score          0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes          0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget         0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross          0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime        0.075077  0.414068  0.352303  0.318695  0.275796  1.000000
# released_year  0.998726  0.061923  0.203098  0.320312  0.268721  0.075294
#
#                released_year
# year                0.998726
# score               0.061923
# votes               0.203098
# budget              0.320312
# gross               0.268721
# runtime             0.075294
# released_year       1.000000

# %%
# The more the budget, the more the gross revenue

# %%
# Visualize the correlation (for numeric values only)

correlation_matrix = df.corr(numeric_only=True)

sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Matrix for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
# Looking at companies

df.head()
# Out:
#                                             name rating   genre  year  \
# 3731                                      Avatar  PG-13  Action  2009
# 5302                           Avengers: Endgame  PG-13  Action  2019
# 1795                                     Titanic  PG-13   Drama  1997
# 4730  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 5158                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 3731  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 5302     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 1795  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 4730  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 5158     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country     budget  \
# ...

# %%
# Make the company names to numerics

df_num = df.copy()

for col_name in df_num.columns:
    if df_num[col_name].dtype == 'object':
        df_num[col_name] = df_num[col_name].astype('category')
        df_num[col_name] = df_num[col_name].cat.codes

df_num.head()
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 3731   386       5      0  2009       527    7.8  1100000.0       785    1263
# 5302   388       5      0  2019       137    8.4   903000.0       105     513
# 1795  4909       5      6  1997       534    7.8  1100000.0       785    1263
# 4730  3643       5      0  2015       529    7.8   876000.0       768    1806
# 5158   389       5      0  2018       145    8.4   897000.0       105     513
#
#       star  country     budget       gross  company  runtime  released_year
# 3731  1534       47  237000000  2847246203     1382    162.0           2009
# 5302  1470       47  356000000  2797501328      983    181.0           2019
# 1795  1073       47  200000000  2201647264     1382    194.0           1997
# 4730   356       47  245000000  2069521700      945    138.0           2015
# 5158  1470       47  321000000  2048359754      983    149.0           2018

# %%
# Compare with the original dataframe
df.head()
# Out:
#                                             name rating   genre  year  \
# 3731                                      Avatar  PG-13  Action  2009
# 5302                           Avengers: Endgame  PG-13  Action  2019
# 1795                                     Titanic  PG-13   Drama  1997
# 4730  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 5158                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 3731  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 5302     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 1795  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 4730  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 5158     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country     budget  \
# ...

# %%
# Visualize the correlation

correlation_matrix = df_num.corr()

sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Matrix for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
# Looking at specific factors

# Correlation matrix

corr_matrix = df_num.corr()

# Choose the upper triangle from the correlation matrix to avoid redundancy
# ex) released_year & year 0.998726, year & released_year 0.998726

upper_triangle = np.triu(correlation_mat, k=1)

# Find the indices of non-zero values in the upper triangle
nonzero_indices = np.where(upper_triangle != 0)

# Create a DataFrame with the correlation pairs and values
corr_pairs = pd.DataFrame({
    'factor1': corr_matrix.index[nonzero_indices[0]],
    'factor2': corr_matrix.columns[nonzero_indices[1]],
    'correlation': corr_matrix.values[nonzero_indices]
})

# Display the unique correlations, sorted in descending order
unique_correlations = corr_pairs.drop_duplicates(subset=['factor1', 'factor2']).sort_values(by='correlation', ascending=False)
print(unique_correlations)
# Out:
#     factor1        factor2  correlation
# 53     year  released_year     0.998726
# 110  budget          gross     0.740247
# 80    votes          gross     0.614751
# 65    score          votes     0.474256
# 79    votes         budget     0.439675
# ..      ...            ...          ...
# 32    genre          votes    -0.135990
# 25   rating          gross    -0.181906
# 24   rating         budget    -0.203946
# 38    genre          gross    -0.244101
# 37    genre         budget    -0.368523
#
# [120 rows x 3 columns]

# %%
# Pairs with correlation greater than 0.5

high_corr = unique_correlations[unique_correlations['correlation'] > 0.5]
high_corr
# Out:
#     factor1        factor2  correlation
# 53     year  released_year     0.998726
# 110  budget          gross     0.740247
# 80    votes          gross     0.614751

# %%
# Hypothesis 1: The more the budget, the more the gross revenue
# -> Seemed to be worth investigating more in the future project!

# Hypothesis 2: Certain companies elicit more gross revenue than others
# -> Unlikely
